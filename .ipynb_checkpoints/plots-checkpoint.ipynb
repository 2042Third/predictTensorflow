# %%
import numpy as np
import pandas as pd
# %matplotlib inline  
import matplotlib
import matplotlib.pyplot as plt  
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from collections import Counter

# %% [markdown]
# ### Van Diagram

# %%
for_="fullpath"
ff="overall"
ext="2019"
# ttl = 3094169
# t = 3094169
ttl = 1207912 # 2019
t = 1207912 # 2019

# po=30182 # org 2021
# po=51493 # proj 2021
# po=ttl # filewise 2021

po=49456 # org 2019
po=70826 # proj 2019
po=ttl # filewise 2019

dec_org_d = pd.read_csv('../outputs/{}/venn/venn_decorators_{}.csv'.format(ff,ext))
dec_org = dec_org_d[[for_]]
func_org_d = pd.read_csv('../outputs/{}/venn/venn_functional_{}.csv'.format(ff,ext))
func_org = func_org_d[[for_]]
dyn_org_d = pd.read_csv('../outputs/{}/venn/venn_dynamic_{}.csv'.format(ff,ext))
dyn_org = dyn_org_d[[for_]]

# %%
#Get the set of the dataframe
def gset(a,b):
    return set(a[b])
dyn_set = gset(dyn_org,for_)
func_set = gset(func_org,for_)
dec_set = gset(dec_org,for_)

# %%
subsets = (1, 1, 0.2, 1, 0.2, 0.2, 0.1)

colors = ['darkviolet','deepskyblue','blue']
v2 = venn3(subsets=subsets, alpha=0.7,set_colors=colors)
labels = ['Dynamic', 'Functional', 'Decorators']
labels = ['100', '101', '110', '010', '001', '011', '111']
for label in labels:
    v2.get_label_by_id(label).set_text(label)

# %%
print(dyn_org)
# Out:
#                                                  fullpath
# 0       repo-python/007gzsdjango_restframework_apiview...
# 1       repo-python/007gzsdjango_restframework_apiview...
# 2       repo-python/007gzsdjango_restframework_apiview...
# 3       repo-python/007gzsdjango_restframework_apiview...
# 4       repo-python/007gzsdjango_restframework_apiview...
# ...                                                   ...
# 112476  repo-python/zzzeeksqlalchemylibsqlalchemysqlcl...
# 112477  repo-python/zzzeeksqlalchemylibsqlalchemysqlde...
# 112478  repo-python/zzzeeksqlalchemylibsqlalchemysqlvi...
# 112479  repo-python/zzzeeksqlalchemylibsqlalchemyutilc...
# 112480  repo-python/zzzeeksqlalchemylibsqlalchemyutild...
#
# [112481 rows x 1 columns]

# %%
plt.figure(figsize=(10,10))
ax = plt.gca()

colors = ['darkviolet','deepskyblue','blue']
labels=('','','')
sets=[dyn_set, func_set, dec_set]
v = venn3(subsets=sets, set_labels=labels, alpha=0.7,set_colors=colors)
i=0
for text in v.set_labels:
  text.set_color(colors[i])
  i+=1
    
id_labels = ['100', '101', '110', '010', '001', '011', '111']
subset_labels=[v.get_label_by_id('110'),v.get_label_by_id('111'),v.get_label_by_id('011'),v.get_label_by_id('010')]
# print(subset_labels)
for i in id_labels:
  text = v.get_label_by_id(i)
  print(text.get_text())
  text.set_color('white')
  text.set_fontsize(16)
  text.set_fontweight('bold')
set_ids=id_labels
h = [] 
for i in set_ids:
    h.append(v.get_patch_by_id(i)) 
l = ['Dyn Only','Dyn & Dec','Func & Dyn','Func Only','Dec Only','Func & Dec','Func & Dyn & Dec']
l = [l[x]+" ("+"{:.2f}%".format(100*int(v.get_label_by_id(id_labels[x]).get_text())/po)+")" for x in range(len(l))]
ax.legend(handles=h, labels=l, title="Legend",loc='lower left') 

plt.title("{} Feature Count".format(for_))
i = 0

plt.gca().set_facecolor('azure')
plt.gca().set_label('all files')

plt.gca().set_axis_on()
plt.show()
# Out:
# 46955
# 11615
# 35408
# 230674
# 91013
# 54477
# 18283

# %%
# print(dyn_set)
# v = venn3([dyn_set, func_set, dec_set], ('Dynamic', 'Functional', 'Decorators'))
plt.figure(figsize=(10,10))
ax = plt.gca()

colors = ['darkviolet','deepskyblue']
labels=('','')
sets=[dyn_set,  dec_set]
v = venn2(subsets=sets, set_labels=labels, alpha=0.7,set_colors=colors)
# fig = plt.figure()
# v = venn3([dyn_set, Functional, dec_set], ('Dynamic',  'Decorators'))
i=0
for text in v.set_labels:
  text.set_color(colors[i])
  i+=1
subset_labels=[v.get_label_by_id('10'),v.get_label_by_id('11'),v.get_label_by_id('01')]
for text in subset_labels:
  text.set_color('white')
  text.set_fontsize(16)
  text.set_fontweight('bold')
set_ids=['10','11','01']
h = [] 
for i in set_ids:
    h.append(v.get_patch_by_id(i)) 
l = ['Dyn only' , 'Dyn & Dec', 'Dec only']
id_labels=['10','11','01']
l = [l[x]+" ("+"{:.2f}%".format(100*int(v.get_label_by_id(id_labels[x]).get_text())/po)+")" for x in range(len(l))]
ax.legend(handles=h, labels=l, title="Legend",loc='lower left') 


plt.title("{} Feature Count".format(for_))
i = 0

plt.gca().set_facecolor('azure')
plt.gca().set_label('all files')

# plt.gca().set_edgecolor('white')

# plt.figure(linewidth=10, edgecolor="black", facecolor="white")
plt.gca().set_axis_on()
plt.show()

# %%
print(11916/len(dyn_set))
print(11916/len(dec_set))
# Out:
# 0.10614550021824141
# 0.06794079412502566

# %%
plt.figure(figsize=(10,10))
ax = plt.gca()

colors = ['blue','deepskyblue']
labels=('','')
sets=[func_set,  dec_set]
v = venn2(subsets=sets, set_labels=labels, alpha=0.7,set_colors=colors)
# fig = plt.figure()
# v = venn3([dyn_set, Functional, dec_set], ('Dynamic',  'Decorators'))
i=0
for text in v.set_labels:
  text.set_color(colors[i])
  i+=1
subset_labels=[v.get_label_by_id('10'),v.get_label_by_id('11'),v.get_label_by_id('01')]
for text in subset_labels:
  text.set_color('white')
  text.set_fontsize(16)
  text.set_fontweight('bold')
set_ids=['10','11','01']
h = [] 
for i in set_ids:
    h.append(v.get_patch_by_id(i)) 
l = ['Func only' , 'Func & Dec', 'Dec only']
id_labels=['10','11','01']
l = [l[x]+" ("+"{:.2f}%".format(100*int(v.get_label_by_id(id_labels[x]).get_text())/po)+")" for x in range(len(l))]
ax.legend(handles=h, labels=l, title="Legend",loc='lower left') 


plt.title("{} Feature Count".format(for_))
i = 0

plt.gca().set_facecolor('azure')
plt.gca().set_label('all files')

# plt.gca().set_edgecolor('white')

# plt.figure(linewidth=10, edgecolor="black", facecolor="white")
plt.gca().set_axis_on()
plt.show()

# %%
plt.figure(figsize=(10,10))
ax = plt.gca()

colors = ['blue','darkviolet']
labels=('','')
sets=[func_set,  dyn_set]
v = venn2(subsets=sets, set_labels=labels, alpha=0.7,set_colors=colors)
# fig = plt.figure()
# v = venn3([dyn_set, Functional, dec_set], ('Dynamic',  'Decorators'))
i=0
for text in v.set_labels:
  text.set_color(colors[i])
  i+=1
subset_labels=[v.get_label_by_id('10'),v.get_label_by_id('11'),v.get_label_by_id('01')]
for text in subset_labels:
  text.set_color('white')
  text.set_fontsize(16)
  text.set_fontweight('bold')
set_ids=['10','11','01']
h = [] 
for i in set_ids:
    h.append(v.get_patch_by_id(i)) 
l = ['Func only' , 'Func & Dyn', 'Dyn only']
id_labels=['10','11','01']
l = [l[x]+" ("+"{:.2f}%".format(100*int(v.get_label_by_id(id_labels[x]).get_text())/po)+")" for x in range(len(l))]
ax.legend(handles=h, labels=l, title="Legend",loc='lower left') 


plt.title("{} Feature Count".format(for_))
i = 0

plt.gca().set_facecolor('azure')
plt.gca().set_label('all files')

# plt.gca().set_edgecolor('white')

# plt.figure(linewidth=10, edgecolor="black", facecolor="white")
plt.gca().set_axis_on()
plt.show()

# %% [markdown]
# ### Histogram

# %%
func_freq_d = pd.read_csv('../outputs/functional_frequency_rank.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['funcname']]

# %%
def valuelabel(func_freq,func_freq_name):
    for i in range(len(func_freq)):
        plt.text(i,func_freq_name[i],func_freq_name[i], ha = 'center')
def valuelabel_r(func_freq,func_freq_name):
    adder = func_freq_name[0]*0.04
    for i in range(len(func_freq)):
        plt.text(i,func_freq_name[i]+adder,func_freq_name[i], ha = 'center', rotation=90)

# %%
plt.figure(figsize=(10,5))
y_pos = np.arange(len(func_freq_name))
plt.bar(y_pos, func_freq['freq'], color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, func_freq_name['funcname'])

plt.title('Functional Feature Ranking')

valuelabel(func_freq_name['funcname'], func_freq['freq'])    
plt.gca().set_facecolor('azure')
plt.show()

# %%
func_freq_d = pd.read_csv('../outputs/decorators_frequency_rank.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['funcname']]

def fix_ext(a):
    b=list()
    for i in a:
        b.append(i[:-4])
    return b
plt.figure(figsize=(25,10))
y_pos = np.arange(len(func_freq_name))
plt.bar(y_pos, func_freq['freq'], color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, fix_ext(func_freq_name['funcname']), rotation=90)
# print(func_freq_name['funcname'])
plt.title('Decorators Feature Ranking (85% of all decorator usage)')

valuelabel_r(func_freq_name['funcname'], func_freq['freq'])    
plt.gca().set_facecolor('azure')
plt.show()

# %%
func_freq_d = pd.read_csv('../outputs/dynamic_frequency_rank.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['funcname']]

plt.figure(figsize=(10,5))
y_pos = np.arange(len(func_freq_name))
plt.bar(y_pos, func_freq['freq'], color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, func_freq_name['funcname'])

plt.title('Dynamic Feature Ranking')

valuelabel(func_freq_name['funcname'], func_freq['freq'])    
plt.gca().set_facecolor('azure')
plt.rcParams.update({'font.size': 9})
plt.show()

# %%
func_freq_d = pd.read_csv('../outputs/async_frequency_rank.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['funcname']]

plt.figure(figsize=(40,10))
y_pos = np.arange(len(func_freq_name))
plt.bar(y_pos, func_freq['freq'], color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, func_freq_name['funcname'], rotation=90)

plt.title('Async Feature Ranking')

valuelabel_r(func_freq_name['funcname'], func_freq['freq'])    
plt.gca().set_facecolor('azure')
plt.rcParams.update({'font.size': 24})
plt.show()

# %%
func_freq_d = pd.read_csv('../outputs/filewise_frequency_with_stats.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['funcname']]

plt.figure(figsize=(40,10))
y_pos = np.arange(len(func_freq_name))
plt.bar(y_pos, func_freq['freq'], color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, func_freq_name['funcname'], rotation=90)

plt.title('With Feature Ranking')

valuelabel_r(func_freq_name['funcname'], func_freq['freq'])    
plt.gca().set_facecolor('azure')
plt.rcParams.update({'font.size': 24})
plt.show()

# %%
func_freq_d = pd.read_csv('../outputs/filewise_frequency_with_stats_new.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['funcname']]
rate=0.90
func_c=0
nums=0
count_stop=35
for i in func_freq["freq"]:
    if(i=="freq"):
        continue
#     print(i)
    func_c=func_c+int(i)
    if func_c/555174 > rate:
        break
    if nums > count_stop:
        rate=func_c/555174
        break
    nums+=1
print("{} top {} with accounts for {}% ".format(func_c,nums,rate*100))
# Out:
# 317064 top 36 with accounts for 57.11074365874482%

# %% [markdown]
# ### Treemap

# %%
# import squarify  
# plt.figure(figsize=(30,30))
func_freq_d = pd.read_csv('../outputs/overall/table_overlap_2019.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['features']]

# plt.title('Overall Proportions')
# a = [3844561]+list(func_freq["freq"])
# b = ["Other Files"]+list(func_freq_name['features'])
# df = pd.DataFrame({'nb_people':a, 'group':b })
# c = ["{}\n({})".format(b[i],a[i])for i in range(len(a))]
# squarify.plot(sizes=df['nb_people'], label=c, alpha=.8 )
# plt.axis('off')
# plt.show()

plt.figure(figsize=(20,10))
y_pos = np.arange(len(func_freq_name))
plt.bar(y_pos, func_freq['freq'], color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(y_pos, func_freq_name['features'], rotation=90)

plt.title('All Feature Ranking')

valuelabel_r(func_freq_name['features'], func_freq['freq'])    
plt.gca().set_facecolor('azure')
plt.show()

# %%
func_freq_d = pd.read_csv('../outputs/overall/table_overlap_2021.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['features']]

freq=func_freq['freq']
names=func_freq_name['features']

ac=0
for i in freq:
    t=t-i
    ac=ac+i
print(ac+t)
print(ttl)
nftr= t# no feature

print('{} & {:,} & {:.3f}\\tabularnewline'.format("no target feature",nftr,(nftr/ttl)*100))
for i in range(len(freq)):
    print('{} & {:,} & {:.3f}\\tabularnewline'.format(names[i],freq[i],(freq[i]/ttl)*100))
# Out:
# 1207912
# 1207912
# no target feature & -64,063 & -5.304\tabularnewline
#  FNL & 365,869 & 30.289\tabularnewline
#  WTH & 146,389 & 12.119\tabularnewline
#  DEC & 126,778 & 10.496\tabularnewline
#  FNL DYN & 113,120 & 9.365\tabularnewline
#  DYN & 112,020 & 9.274\tabularnewline
#  FNL WTH & 98,827 & 8.182\tabularnewline
#  FNL DEC & 77,458 & 6.413\tabularnewline
#  FNL DYN DEC & 63,908 & 5.291\tabularnewline
#  FNL DEC WTH & 33,101 & 2.740\tabularnewline
#  FNL DYN DEC WTH & 32,739 & 2.710\tabularnewline
#  FNL DYN WTH & 31,393 & 2.599\tabularnewline
#  DYN DEC & 25,692 & 2.127\tabularnewline
#  DEC WTH & 20,542 & 1.701\tabularnewline
#  DYN WTH & 17,373 & 1.438\tabularnewline
#  DYN DEC WTH & 4,808 & 0.398\tabularnewline
#  DEC ASC & 355 & 0.029\tabularnewline
#  ASC & 317 & 0.026\tabularnewline
#  FNL DEC ASC & 281 & 0.023\tabularnewline
#  FNL ASC & 172 & 0.014\tabularnewline
#  FNL DYN DEC ASC & 157 & 0.013\tabularnewline
# nan & 127 & 0.011\tabularnewline
#  FNL DEC WTH ASC & 123 & 0.010\tabularnewline
#  DEC WTH ASC & 91 & 0.008\tabularnewline
#  FNL WTH ASC & 82 & 0.007\tabularnewline
#  WTH ASC & 68 & 0.006\tabularnewline
#  FNL DYN DEC WTH ASC & 51 & 0.004\tabularnewline
#  FNL DYN ASC & 50 & 0.004\tabularnewline
#  DYN DEC ASC & 42 & 0.003\tabularnewline
#  DYN ASC & 16 & 0.001\tabularnewline
#  FNL DYN WTH ASC & 14 & 0.001\tabularnewline
#  DYN DEC WTH ASC & 8 & 0.001\tabularnewline
#  DYN WTH ASC & 4 & 0.000\tabularnewline

# %%
func_freq_d = pd.read_csv('../outputs/overall/table_standalone_2021.csv')
func_freq = func_freq_d[['freq']]
func_freq_name = func_freq_d[['feature']]

freq=func_freq['freq']
names=func_freq_name['feature']

ac=0
for i in freq:
    t=t-i
    ac=ac+i
print(ac+t)
print(ttl)
nftr= t# no feature

print('{} & {:,} & {:.3f}\\tabularnewline'.format("no target feature",nftr,(nftr/ttl)*100))
for i in range(len(freq)):
    print('{} & {:,} & {:.3f}\\tabularnewline'.format(names[i],freq[i],(freq[i]/ttl)*100))
# Out:
# -64063
# 1207912
# no target feature & -2,056,381 & -170.243\tabularnewline
# FNL & 817,345 & 67.666\tabularnewline
# DYN & 401,395 & 33.230\tabularnewline
# DEC & 386,134 & 31.967\tabularnewline
# WTH & 385,613 & 31.924\tabularnewline
# ASC & 1,831 & 0.152\tabularnewline
